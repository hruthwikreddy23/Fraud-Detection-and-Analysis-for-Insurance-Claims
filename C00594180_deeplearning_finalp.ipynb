# %%
# Import Required Libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, classification_report
)
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# For reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

pd.set_option("display.max_columns", None)

# %%
# Load Dataset

import pandas as pd

DATA_PATH = "/content/insurance_claims.csv"

df = pd.read_csv(DATA_PATH)

print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (1000, 40)
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft                ?      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                   NaN             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
# Initial Data Exploration

empty_cols = [c for c in df.columns if df[c].isna().all()]
if empty_cols:
    print("Dropping empty columns:", empty_cols)
    df.drop(columns=empty_cols, inplace=True)


print("fraud_reported value counts before encoding:")
print(df['fraud_reported'].value_counts())


df['fraud_reported'] = df['fraud_reported'].map({'Y': 1, 'N': 0}).astype(int)

print("\nfraud_reported value counts after encoding:")
print(df['fraud_reported'].value_counts())


sns.countplot(x=df['fraud_reported'])
plt.title("Class Distribution (0 = Genuine, 1 = Fraud)")
plt.show()
# Out:
# Dropping empty columns: ['_c39']
# fraud_reported value counts before encoding:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
#
# fraud_reported value counts after encoding:
# fraud_reported
# 0    753
# 1    247
# Name: count, dtype: int64

# %%
# Check Class Distribution

TARGET_COL = "fraud_reported"


id_like_cols = [
    "policy_number",
    "policy_bind_date",
    "incident_date",
    "incident_location",
    "insured_zip",
    "policy_csl"
]


id_like_cols = [c for c in id_like_cols if c in df.columns]

print("Dropping ID-like columns (if present):", id_like_cols)


X = df.drop(columns=[TARGET_COL] + id_like_cols, errors="ignore")
y = df[TARGET_COL]

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)


numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

print("\nNumeric features:")
print(numeric_features)

print("\nCategorical features:")
print(categorical_features)
# Out:
# Dropping ID-like columns (if present): ['policy_number', 'policy_bind_date', 'incident_date', 'incident_location', 'insured_zip', 'policy_csl']
# Shape of X: (1000, 32)
# Shape of y: (1000,)
#
# Numeric features:
# ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']
#
# Categorical features:
# ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %%
# Data Preprocessing (Encoding + Scaling + Train/Test Split)

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])


categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])


preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=SEED
)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)

print("\nTraining label distribution:")
print(y_train.value_counts())

print("\nTesting label distribution:")
print(y_test.value_counts())
# Out:
# Training set shape: (800, 32)
# Testing set shape: (200, 32)
#
# Training label distribution:
# fraud_reported
# 0    602
# 1    198
# Name: count, dtype: int64
#
# Testing label distribution:
# fraud_reported
# 0    151
# 1     49
# Name: count, dtype: int64

# %%
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

print("Transformed training shape:", X_train_processed.shape)
print("Transformed testing shape:", X_test_processed.shape)


input_dim = X_train_processed.shape[1]
print("Input dimension for neural networks:", input_dim)
# Out:
# Transformed training shape: (800, 157)
# Transformed testing shape: (200, 157)
# Input dimension for neural networks: 157

# %%
# Compute Class Weights for ANN

if hasattr(X_train_processed, "toarray"):
    X_train_np = X_train_processed.toarray()
    X_test_np = X_test_processed.toarray()
else:
    X_train_np = X_train_processed
    X_test_np = X_test_processed

print("Dense training shape:", X_train_np.shape)
print("Dense testing shape:", X_test_np.shape)


classes = np.unique(y_train)
weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)
class_weights = dict(zip(classes, weights))

print("Class weights:", class_weights)
# Out:
# Dense training shape: (800, 157)
# Dense testing shape: (200, 157)
# Class weights: {np.int64(0): np.float64(0.6644518272425249), np.int64(1): np.float64(2.0202020202020203)}

# %%
# Build the ANN Model

def build_ann(input_dim):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(64, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(1, activation="sigmoid")  # binary output
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy", keras.metrics.AUC(name="auc")]
    )
    return model

ann_model = build_ann(input_dim)
ann_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 64)             │        10,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,225 (47.75 KB)
#  Trainable params: 12,225 (47.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the ANN Model

early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history_ann = ann_model.fit(
    X_train_np,
    y_train,
    epochs=50,
    batch_size=256,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.4295 - auc: 0.5408 - loss: 0.6945 - val_accuracy: 0.4688 - val_auc: 0.5307 - val_loss: 0.7167
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5534 - auc: 0.6357 - loss: 0.6728 - val_accuracy: 0.5063 - val_auc: 0.5489 - val_loss: 0.6919
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6446 - auc: 0.6896 - loss: 0.6572 - val_accuracy: 0.5813 - val_auc: 0.5642 - val_loss: 0.6727
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6972 - auc: 0.7264 - loss: 0.6436 - val_accuracy: 0.6062 - val_auc: 0.5706 - val_loss: 0.6594
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7187 - auc: 0.7567 - loss: 0.6307 - val_accuracy: 0.6062 - val_auc: 0.5846 - val_loss: 0.6503
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7376 - auc: 0.7791 - loss: 0.6179 - val_accuracy: 0.6187 - val_auc: 0.5948 - val_loss: 0.6446
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7502 - auc: 0.7973 - loss: 0.6048 - val_accuracy: 0.6187 - val_auc: 0.6012 - val_loss: 0.6413
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7684 - auc: 0.8135 - loss: 0.5914 - val_accuracy: 0.6250 - val_auc: 0.6073 - val_loss: 0.6394
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7757 - auc: 0.8268 - loss: 0.5776 - val_accuracy: 0.6062 - val_auc: 0.6082 - val_loss: 0.6377
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7762 - auc: 0.8411 - loss: 0.5635 - val_accuracy: 0.6187 - val_auc: 0.6121 - val_loss: 0.6355
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7810 - auc: 0.8548 - loss: 0.5492 - val_accuracy: 0.6125 - val_auc: 0.6205 - val_loss: 0.6327
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7935 - auc: 0.8680 - loss: 0.5346 - val_accuracy: 0.6250 - val_auc: 0.6276 - val_loss: 0.6293
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7995 - auc: 0.8805 - loss: 0.5194 - val_accuracy: 0.6438 - val_auc: 0.6320 - val_loss: 0.6256
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8101 - auc: 0.8922 - loss: 0.5037 - val_accuracy: 0.6500 - val_auc: 0.6355 - val_loss: 0.6217
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8242 - auc: 0.9038 - loss: 0.4878 - val_accuracy: 0.6438 - val_auc: 0.6387 - val_loss: 0.6174
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8399 - auc: 0.9138 - loss: 0.4715 - val_accuracy: 0.6375 - val_auc: 0.6411 - val_loss: 0.6130
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8468 - auc: 0.9223 - loss: 0.4548 - val_accuracy: 0.6438 - val_auc: 0.6472 - val_loss: 0.6087
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8587 - auc: 0.9306 - loss: 0.4377 - val_accuracy: 0.6438 - val_auc: 0.6521 - val_loss: 0.6045
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8700 - auc: 0.9383 - loss: 0.4202 - val_accuracy: 0.6438 - val_auc: 0.6579 - val_loss: 0.6004
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8776 - auc: 0.9447 - loss: 0.4026 - val_accuracy: 0.6500 - val_auc: 0.6661 - val_loss: 0.5962
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8858 - auc: 0.9508 - loss: 0.3849 - val_accuracy: 0.6687 - val_auc: 0.6753 - val_loss: 0.5920
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8899 - auc: 0.9557 - loss: 0.3675 - val_accuracy: 0.6562 - val_auc: 0.6803 - val_loss: 0.5882
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8890 - auc: 0.9601 - loss: 0.3504 - val_accuracy: 0.6625 - val_auc: 0.6892 - val_loss: 0.5848
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8968 - auc: 0.9646 - loss: 0.3336 - val_accuracy: 0.6562 - val_auc: 0.6950 - val_loss: 0.5815
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9003 - auc: 0.9685 - loss: 0.3173 - val_accuracy: 0.6625 - val_auc: 0.7026 - val_loss: 0.5780
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9108 - auc: 0.9722 - loss: 0.3014 - val_accuracy: 0.6750 - val_auc: 0.7105 - val_loss: 0.5747
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9131 - auc: 0.9754 - loss: 0.2858 - val_accuracy: 0.6812 - val_auc: 0.7176 - val_loss: 0.5715
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9153 - auc: 0.9784 - loss: 0.2708 - val_accuracy: 0.7000 - val_auc: 0.7233 - val_loss: 0.5687
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9224 - auc: 0.9813 - loss: 0.2560 - val_accuracy: 0.7063 - val_auc: 0.7305 - val_loss: 0.5662
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9262 - auc: 0.9837 - loss: 0.2417 - val_accuracy: 0.7125 - val_auc: 0.7354 - val_loss: 0.5638
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9312 - auc: 0.9862 - loss: 0.2279 - val_accuracy: 0.7188 - val_auc: 0.7394 - val_loss: 0.5619
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9440 - auc: 0.9884 - loss: 0.2145 - val_accuracy: 0.7188 - val_auc: 0.7445 - val_loss: 0.5605
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9552 - auc: 0.9905 - loss: 0.2015 - val_accuracy: 0.7188 - val_auc: 0.7507 - val_loss: 0.5595
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9582 - auc: 0.9924 - loss: 0.1890 - val_accuracy: 0.7250 - val_auc: 0.7555 - val_loss: 0.5584
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9655 - auc: 0.9941 - loss: 0.1769 - val_accuracy: 0.7437 - val_auc: 0.7572 - val_loss: 0.5577
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9690 - auc: 0.9953 - loss: 0.1654 - val_accuracy: 0.7500 - val_auc: 0.7591 - val_loss: 0.5577
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9748 - auc: 0.9964 - loss: 0.1544 - val_accuracy: 0.7437 - val_auc: 0.7616 - val_loss: 0.5583
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9796 - auc: 0.9972 - loss: 0.1439 - val_accuracy: 0.7500 - val_auc: 0.7658 - val_loss: 0.5597
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9796 - auc: 0.9979 - loss: 0.1341 - val_accuracy: 0.7500 - val_auc: 0.7687 - val_loss: 0.5617
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9809 - auc: 0.9984 - loss: 0.1248 - val_accuracy: 0.7437 - val_auc: 0.7701 - val_loss: 0.5644
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9844 - auc: 0.9988 - loss: 0.1159 - val_accuracy: 0.7375 - val_auc: 0.7716 - val_loss: 0.5674

# %%
# Plot ANN Training Loss and Accuracy

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, classification_report
)

def print_metrics(y_true, y_pred, y_proba):
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    auc = roc_auc_score(y_true, y_proba)

    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1-score : {f1:.4f}")
    print(f"ROC-AUC  : {auc:.4f}")

# %%
# Evaluate ANN Performance on Test Set

y_proba_ann = ann_model.predict(X_test_np).ravel()
y_pred_ann = (y_proba_ann >= 0.5).astype(int)

print("=== ANN performance on test set ===")
print_metrics(y_test, y_pred_ann, y_proba_ann)

print("\nClassification report:")
print(classification_report(y_test, y_pred_ann, zero_division=0))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === ANN performance on test set ===
# Accuracy : 0.7300
# Precision: 0.4545
# Recall   : 0.5102
# F1-score : 0.4808
# ROC-AUC  : 0.7701
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       151
#            1       0.45      0.51      0.48        49
#
#     accuracy                           0.73       200
#    macro avg       0.64      0.66      0.65       200
# weighted avg       0.74      0.73      0.74       200

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Loss
axes[0].plot(history_ann.history["loss"], label="train")
axes[0].plot(history_ann.history["val_loss"], label="val")
axes[0].set_title("ANN – Loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Binary crossentropy")
axes[0].legend()

# Accuracy
axes[1].plot(history_ann.history["accuracy"], label="train")
axes[1].plot(history_ann.history["val_accuracy"], label="val")
axes[1].set_title("ANN – Accuracy")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Plot ANN ROC Curve

fpr, tpr, _ = roc_curve(y_test, y_proba_ann)
auc_ann = roc_auc_score(y_test, y_proba_ann)

plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"ANN (AUC = {auc_ann:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve – ANN")
plt.legend()
plt.show()

# %%
# plot precision- recall curve

from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt


precision, recall, _ = precision_recall_curve(y_test, y_proba_ann)
avg_prec = average_precision_score(y_test, y_proba_ann)

plt.figure(figsize=(6, 6))
plt.step(recall, precision, where="post")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision–Recall Curve – ANN (Average Precision = {avg_prec:.3f})")
plt.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# ANN Confusion Matrix

import seaborn as sns

def plot_confusion(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(4, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["Genuine", "Fraud"],
                yticklabels=["Genuine", "Fraud"])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(title)
    plt.show()

plot_confusion(y_test, y_pred_ann, "Confusion Matrix – ANN")

# %%
# Built Autoencoder Model

X_train_genuine = X_train_np[y_train == 0]

def build_autoencoder(input_dim):
    inp = layers.Input(shape=(input_dim,))
    x = layers.Dense(64, activation="relu")(inp)
    x = layers.Dense(32, activation="relu")(x)
    bottleneck = layers.Dense(16, activation="relu")(x)

    x = layers.Dense(32, activation="relu")(bottleneck)
    x = layers.Dense(64, activation="relu")(x)
    out = layers.Dense(input_dim, activation="linear")(x)

    autoencoder = keras.Model(inp, out)
    autoencoder.compile(optimizer="adam", loss="mse")
    return autoencoder

ae_model = build_autoencoder(input_dim)
ae_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 157)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │        10,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 157)            │        10,205 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,581 (99.93 KB)
#  Trainable params: 25,581 (99.93 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Autoencoder

early_stop_ae = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history_ae = ae_model.fit(
    X_train_genuine,
    X_train_genuine,
    epochs=50,
    batch_size=256,
    validation_split=0.2,
    callbacks=[early_stop_ae],
    verbose=1
)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - loss: 0.2068 - val_loss: 0.2039
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2044 - val_loss: 0.2025
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2027 - val_loss: 0.2013
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2014 - val_loss: 0.2001
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2000 - val_loss: 0.1987
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1985 - val_loss: 0.1971
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1967 - val_loss: 0.1953
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1945 - val_loss: 0.1932
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1921 - val_loss: 0.1909
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1896 - val_loss: 0.1885
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1871 - val_loss: 0.1862
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1848 - val_loss: 0.1839
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1824 - val_loss: 0.1814
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1798 - val_loss: 0.1789
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1773 - val_loss: 0.1765
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1748 - val_loss: 0.1742
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1724 - val_loss: 0.1719
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1700 - val_loss: 0.1696
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1677 - val_loss: 0.1673
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1653 - val_loss: 0.1650
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1630 - val_loss: 0.1627
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1606 - val_loss: 0.1604
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1583 - val_loss: 0.1582
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1562 - val_loss: 0.1563
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1542 - val_loss: 0.1545
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1524 - val_loss: 0.1530
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1507 - val_loss: 0.1516
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1492 - val_loss: 0.1503
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1477 - val_loss: 0.1490
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1463 - val_loss: 0.1478
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1449 - val_loss: 0.1467
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1435 - val_loss: 0.1456
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1422 - val_loss: 0.1444
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1408 - val_loss: 0.1433
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1395 - val_loss: 0.1422
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1382 - val_loss: 0.1411
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1368 - val_loss: 0.1399
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1354 - val_loss: 0.1388
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1340 - val_loss: 0.1376
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1326 - val_loss: 0.1364
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1311 - val_loss: 0.1352
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1296 - val_loss: 0.1340
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1282 - val_loss: 0.1328
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1268 - val_loss: 0.1317
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1255 - val_loss: 0.1306
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1242 - val_loss: 0.1295
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1229 - val_loss: 0.1284
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1217 - val_loss: 0.1274
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1205 - val_loss: 0.1264
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1193 - val_loss: 0.1253

# %%
X_train_genuine_pred = ae_model.predict(X_train_genuine)
train_mse = np.mean(np.square(X_train_genuine - X_train_genuine_pred), axis=1)


threshold = np.percentile(train_mse, 95)
print("Chosen reconstruction error threshold:", threshold)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Chosen reconstruction error threshold: 0.15584970673039625

# %%
# Autoencoder performance on test set

X_test_pred = ae_model.predict(X_test_np)
test_mse = np.mean(np.square(X_test_np - X_test_pred), axis=1)


y_pred_ae = (test_mse >= threshold).astype(int)

print("=== Autoencoder performance on test set ===")
print_metrics(y_test, y_pred_ae, test_mse)

print("\nClassification report (Autoencoder):")
print(classification_report(y_test, y_pred_ae, zero_division=0))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# === Autoencoder performance on test set ===
# Accuracy : 0.7050
# Precision: 0.3214
# Recall   : 0.1837
# F1-score : 0.2338
# ROC-AUC  : 0.6005
#
# Classification report (Autoencoder):
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82       151
#            1       0.32      0.18      0.23        49
#
#     accuracy                           0.70       200
#    macro avg       0.54      0.53      0.53       200
# weighted avg       0.66      0.70      0.67       200

# %%
# Autoencoder Loss Curve

plt.figure(figsize=(6,4))
plt.plot(history_ae.history["loss"], label="train")
plt.plot(history_ae.history["val_loss"], label="val")
plt.title("Autoencoder – Reconstruction Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.legend()
plt.show()

# %%
# Autoencoder Confusion Matrix

plot_confusion(y_test, y_pred_ae, "Confusion Matrix – Autoencoder")

# %%
# Autoencoder Reconstruction Error Distribution

plt.figure(figsize=(8, 4))

# Genuine
plt.hist(test_mse[y_test == 0], bins=50, alpha=0.6, label="Genuine", density=True)
# Fraud
plt.hist(test_mse[y_test == 1], bins=50, alpha=0.6, label="Fraud", density=True)

plt.xlabel("Reconstruction Error (MSE)")
plt.ylabel("Density")
plt.title("Reconstruction Error Distribution – Autoencoder")
plt.legend()
plt.tight_layout()
plt.show()
